# %%
# Since the code is not complete and throughly tested
# This notebook displays what the final output looks like

# %%
"""
The two images below show how the course of the water way changes overtime. The binary segmented images make it 
easier to calculate the loss of river or land if any due to river transformation. After obtaining the segmentated 
image at different points of time, i intend to write a code to calcuate the change in the 
size of water body / forests (like the output of the cell below). Thus automating the montitoring task.

"""
# Out:
# 6070_2_2
# 6070_2_3

# %%
from IPython.display import Image
Image(filename='./preview_images/change.png', width=500)

# %%
# left hand side above image is detection of water body(yellow part) suppose in the 2002 and the left hand side below image is the 
# same water body in the 2007(yellow part). Finally using these segmented images one can calculate the right hand
# side single image showing a change in the area of the yellow part. (increase by 23%)
# The above image shows that the obtained coverage( this could be forest / city /  water body depending on the 
# model it is trained for ) has increased by 23%
